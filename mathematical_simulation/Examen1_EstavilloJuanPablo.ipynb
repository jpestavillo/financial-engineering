# %% [markdown]
# ## Examen Módulo 1
# > ___Juan Pablo Estavillo___.

# %% [markdown]
#         problema 1 las cosas del amor
#
#
# 1.- Las cosas del amor (35 puntos)
# Consideramos un modelo simple de la dinámica del amor/odio en una pareja,
# propuesto por Strogatz en 1988. (Strogatz, S.H. (1988) Love affairs and differential
# equations, Math. Magazine 61, 35.)
# Romeo está enamorado de Julieta, pero en este caso, Julieta tiene sentimientos
# volubles. Mientras Romeo más la ama, ella quiere huir de él. Pero cuando Romeo
# no muestra atención, Julieta lo empieza a ver muy atractivo.
# Del otro lado, Romeo tiene sentimientos imitativos. Esto quiere decir que se pone
# cariñoso cuando ella lo ama y se vuelve frío cuando ella lo odia.
# Sean:
#  𝑥1(𝑡) : amor/odio de Romeo hacia Julieta en el tiempo t
#  𝑥2(𝑡) : amor/odio de Julieta hacia Romeo en el tiempo t.
# Consideraremos que un valor positivo de 𝑥1 o 𝑥2 corresponde a amor, y que un
# valor negativo corresponde a odio.
# Un modelo del romance anteriormente descrito es
# 𝑑𝑥1
# 𝑑𝑡 = 𝑎𝑥2
# 𝑑𝑥2
# 𝑑𝑡 = −𝑏𝑥1
# con a y b constantes positivas. Definimos 𝑥 = [𝑥1 𝑥2]
# .
# 1. (20 puntos) Simular este sistema eligiendo los parámetros a = b = 1 y
# condiciones iniciales 𝑥(0) = [𝑥1 𝑥2]
# 𝑇 = [5 5]
# 𝑇
# , usando un vector de
# tiempo de 0 a 50 (unidades de tiempo).
# 2. (15 puntos)
# (10 puntos) Graficar las soluciones en el tiempo, es decir, 𝑥1 vs. t y 𝑥2 vs. T
# (5 puntos) ¿Qué forma tienen dichas soluciones? ¿Qué se puede decir del
# amor/odio de Romeo hacia Julieta? ¿Qué se puede decir del amor/odio de
# Julieta hacia Romeo?
# 3. (15 puntos)
# (10 puntos) Graficar el retrato de fase, es decir, 𝑥2 vs. 𝑥1
# (5 puntos) ¿Cómo es el amor de Romeo y Julieta? ¿Considera usted sano
# (en sintonía) este tipo de amor?

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

import matplotlib as mpl

# %%
a=1
b=1
def incisoa (variables,t):
        x1,x2=variables
        return [a*x2, -b*x1]
inicial=[5,5] #estos son datos del problema


tiempo=np.arange(0,50,.01)

resultado = odeint(incisoa,inicial,tiempo)
#odeint para integrar 
xx,yy=resultado.T


label_size= 16
mpl.rcParams['xtick.labelsize']= label_size
mpl.rcParams['xtick.labelsize']= label_size 


plt.plot(tiempo,xx,c= 'k', label="el bato")
plt.plot(tiempo,yy,c='m',label="la chava bipolar")
plt.legend(loc='best',prop={'size':16})
plt.xlabel('',fontsize=14)
plt.show()

# %%
plt.plot(tiempo,xx,c= 'r', label="el bato")

plt.legend(loc='best',prop={'size':16})
plt.xlabel('',fontsize=14)
plt.show()

# %%
plt.plot(tiempo,yy,c='g',label="la chava bipolar")
plt.legend(loc='best',prop={'size':16})
plt.xlabel('',fontsize=14)
plt.show()

# %% [markdown]
# 1: el amor que tienen es un amor correlacionado, ya que romeo empieza a tornarse mas frio debido a julieta y julieta empieza a quererlo otra vez cuando llega a un frialdad alta, es un ciclo sin fin. por lo tanto  su amor es muy voluble. tiene forma de oscilador armonico

# %%
#este es el resulto del amor bipolar de romero y julieta 
x1=resultado[:,0]
x2=resultado[:,1]
plt.figure(figsize = (5, 5))
plt.scatter(x1,x2, cmap = 'viridis', c = x1, s = 100, lw = 5)
plt.xlabel('$la chava bipolar$', fontsize = 18)
plt.ylabel('$el bato$', fontsize = 18)
plt.show()

# %% [markdown]
# este amor no es nada sano, es muy voluble y no tiene una consistencia a traves del tiempo.

# %% [markdown]
# Problema 2  Inundación de pandas y pingüinos (35 puntos)
# Supóngase que la ecuación diferencial que modela el ritmo de crecimiento
# poblacional de pingüinos, en una región de Namibia, se comporta de acuerdo a la
# siguiente ecuación diferencial,
# 𝑑𝑥
# 𝑑𝑡 = −𝑥 𝑟 (1 − 𝑥)
# la población de pingüinos se ha visto disminuida desde que se aplicó fumigante el
# 1 de enero de 2015 para el control de pájaros asesinos que habitan en la zona. Se
# estima que la población para la fecha en que se aplicó el fumigante era de 600
# individuos (que para términos de aplicación en la ecuación diferencial se cuantifican
# al millar, es decir 0.6). El tiempo de afectación del producto es de 10 años y la razón
# de crecimiento es de 0.5
# Por su parte los pandas se sienten más animados a la procreación con alguno de
# los químicos que contiene este poderoso fumigante, y la ecuación que modela el
# comportamiento del crecimiento/decrecimiento poblacional es
# 𝑑𝑥
# 𝑑𝑡 = 𝑥 𝑟 (1 − 𝑥)
# 2
# Para la fecha en que se aplicó el feliz fumigante, la población de pandas se estimaba
# en 600 ositos, y su razón de crecimiento se calcula en 0.1.
# El problema con los osos moteados (pandas) es que atacan a las ovejas de los
# pueblos granjeros. Se ha calculado que los ataques suceden cuando la población
# de pandas rebasa los 700 individuos, por ello es que los granjeros saben que si la
# población aumenta se verán obligados a cazarlos y comérselos (para Navidad y año
# nuevo) ¿En cuánto se estima haya aumentado o disminuido la población de pandas
# para el 31 de diciembre del 2023?, ¿Habrán sobrevivido? ¿superarán este límite de
# armonía en la naturaleza?

# %%
#estos son pinguinos que se estan muriendo
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
#%%
import matplotlib as mpl
label_size = 10
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 
#%%
r = .5
def poblacion(x, t):
    return r * (-x) *(1 - x)
#%%
x0 = .6
 
tt = np.linspace(2015, 2024, 10)
#aqui integramos para que salga chido
xx = odeint(poblacion, x0, tt)
plt.plot(tt, xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
#estos son osos animados y hornies
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
#%%
import matplotlib as mpl
label_size = 10
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 
#%%
r = .1
def poblacion(x, t):
    return r * x *((1 - x)*(1 - x))
#%%
x0 = .6
#va de 0 a 10 en 10 particiones, 
tt = np.linspace(2015, 2024, 10)
#aqui integramos para que salga chido
xx = odeint(poblacion, x0, tt)
plt.plot(tt, xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %% [markdown]
# en el año 2023 la poblacion de pandas será de 666, por lo tanto la población aumentó 66 y no se los van a comer.
# hasta el año 2028 los van a empezar a matar a estos pobres ositos.

# %% [markdown]
# Problema 4
# Se pagará el automóvil con una tasa de interés variable entre 1.5% y 2% mensual
# a) ¿Cuántos automóviles rentados hay en promedio diario? (10 puntos)
# b) ¿Cuántas “días de renta” en promedio se contratan al día (sería la suma los días rentados,
# ejemplo supóngase que un día cualquiera se rentan dos automóviles, uno por 3 días y otro
# por 1 día, el promedio de “días de renta” de ese día fue de 3+1=2) (10 puntos)
# c) ¿Cuál es el número de automóviles que simultáneamente están rentados en promedio por
# día? (10 puntos)
# d) ¿Cuál es el número de automóviles más rentable que se debe tener en el negocio?,
# asumiendo que ya están pagados todos los automóviles y solo se deben de tomar en cuenta
# el ingreso por rentas y el pago por no tener coches disponibles o la pérdida por automóviles
# no rentados por día (20 puntos, estos son extras)

# %%
import numpy as np
import random
"datos problema"
pr0=.1
pr1=.2
pr2=.45
pr3=.75
pr4=1

prd1=.4
prd2=.75
prd3=.9
prd4=1

numerooptimo=0
numerooptimo2=0
incisob=0
incisob2=0
numerodiasmayor=0
b=0

c=0
c1=0 
#%%
"estructura"
"columna0=aleatorionumero"
"columna1=rentahoy"
"columna2= rentados anteriormente se usa for de columna 31-46"
"columna3=disponible = k-rentados  (estos que sobran restan 50 a ganancia"

"columna6=aleatorio interes"
"columna8 sobra de coche"
"columna9=perdidaporfaltadecoche"
"columna10=ganancia"

"columna11-27 existencia carros  (usamos for para llenar esos espacios) "
"columna31-46 0=disponibilidad  numero=diasparaqueesterentado"   
"disponibles=existentes-rentados)"
"columna 51-66 aleatorios dias "
"columna 71-86 numero de dias"
"columna 91-106 dias restantes"
"columna 111-126 "
"columna 131-146 ganancia"
#%%

"declaramos variables"
"k=numero de coches"
"day=numero de dia corriendo"
for n in range (1,2,1):  
        "veces que se ejecuta la simulacion"
        simulacion=np.zeros((366,127,17))
        for k in range (1,17,1): 
            columna11=11
            columna31=31
            columna51=51
            columna71=71
            columna91=91
            columna111=111
            columna131=131
            gananciatotal=0
            perdidatotal=0
            resultado=0
            c=0
            a=0
            
            for i in range (0,365,1):
                "dias"
                simulacion[i,0,k]=random.random()
                
                if  simulacion[i,0,k]<pr0:
                    simulacion[i,1,k]=0
                elif simulacion[i,0,k]<pr1:
                    simulacion[i,1,k]=1
                elif simulacion[i,0,k]<pr2:
                    simulacion[i,1,k]=2   
                elif simulacion[i,0,k]<pr3:
                    simulacion[i,1,k]=3
                elif simulacion[i,0,k]<pr4:
                    simulacion[i,1,k]=4   
                
                simulacion[i,6,k]=random.random()
                simulacion[i,6,k]=(1.5+simulacion[i,6,k])/100
                simulacion[0,2,k]=0
                simulacion[i,3,k]=(k-simulacion[i,2,k]-simulacion[i,1,k])
                
                if simulacion[0,3,k]>0:
                    simulacion[0,4,k]=k-simulacion[0,3,k]
                if simulacion[0,3,k]==0:
                    simulacion[0,4,k]=k
                if simulacion[0,3,k]<0:
                    simulacion[0,4,k]=k
                        
                
                if simulacion [i,3,k]<0:
                    simulacion[i,9,k]=simulacion[i,3,k]
                    simulacion[i,3,k]=0
                    simulacion[i,5,k]=simulacion[i,10,k]
                if simulacion [i,3,k]==0:
                    simulacion[i,10,k]=k
                    simulacion[i,5,k]=simulacion[i,10,k]
                if simulacion[i,3,k]>0: 
                    simulacion[i,10,k]=k-simulacion[i,3,k]
                    simulacion[i,5,k]=simulacion[i,10,k]
               
        
                
                if i>0:    
                    simulacion[i,4,k]=simulacion[i-1,3,k]-simulacion[i,3,k]  
                    if simulacion[i,4,k]<0:
                        simulacion[i,4,k]=0
                if i==0:
                    for contador2 in range(0,k,1):
                        simulacion[0,columna11+contador2,k]=1
                simulacion[i,5,k]=0
                
                
                
                
                for contador in range (0,k,1):
                    if simulacion[i,columna11+contador,k]>1:
                        simulacion[i,5,k]=simulacion[i,5,k]+1
                        
                    if simulacion[i,5,k]<simulacion[i,10,k]:
                       
                            if simulacion[i,columna11+contador,k]==1:                
                                
                
                                    simulacion[i,(columna31)+contador,k]=random.random()
                                    if simulacion[i,(columna31)+contador,k]<prd1:
                                        simulacion[i,(columna11)+contador,k]=2
                                        simulacion[i,5,k]=simulacion[i,5,k]+1
                                        b=b+simulacion[i,(columna11)+contador,k]-1    
                                        numerodiasmayor=numerodiasmayor+1
                                       
                                    elif simulacion[i,(columna31)+contador,k]<prd2:
                                        simulacion[i,(columna11)+contador,k]=3
                                        simulacion[i,5,k]=simulacion[i,5,k]+1
                                        b=b+simulacion[i,(columna11)+contador,k]-1    
                                        numerodiasmayor=numerodiasmayor+1
                                        
                                    elif simulacion[i,(columna31)+contador,k]<prd3:
                                        simulacion[i,(columna11)+contador,k]=4
                                        simulacion[i,5,k]=simulacion[i,5,k]+1
                                        b=b+simulacion[i,(columna11)+contador,k]-1    
                                        numerodiasmayor=numerodiasmayor+1
                                      
                                    elif simulacion[i,(columna31)+contador,k]<prd4:
                                        simulacion[i,(columna11)+contador,k]=5
                                        simulacion[i,5,k]=simulacion[i,5,k]+1
                                        b=b+simulacion[i,(columna11)+contador,k]-1    
                                        numerodiasmayor=numerodiasmayor+1
                                       
                           
                                
                    if simulacion[i,columna11+contador,k]>1:
                        simulacion[i+1,columna11+contador,k]= simulacion[i,(columna11)+contador,k]-1       
                    if simulacion[i,columna11+contador,k]>2:
                        simulacion[i+1,2,k]=simulacion[i+1,2,k]+1
                    if simulacion[i,columna11+contador,k]==1:
                        simulacion[i+1,columna11+contador,k]=1                      
                        
                            
                        
                c=c+simulacion[i,10,k]    
                
                a=a+ simulacion[i,1,k]  
                    
                    
                  
                simulacion[i,5,k]=0
                simulacion[i,8,k]=simulacion[i,3,k]  
                perdidatotal=perdidatotal+simulacion[i,9,k]*-200+ simulacion[i,3,k]*(50)
                gananciatotal=gananciatotal+simulacion[i,10,k]*350
                resultado=gananciatotal-perdidatotal
                if (resultado)>incisob:
                    numerooptimo=k
                    incisob=(resultado)
                if (resultado-75000*k)>incisob2:
                    numerooptimo2=k
                    incisob2=(resultado-75000*k)
                
            print ("ganancia",k,"coches ","=",resultado-75000*k*(1+simulacion[i,6,k]))
            print("inciso a con",k,"coches es",a/365)
            print("inciso b con",k,"coches es",b/numerodiasmayor)
            b=0
            numerodiasmayor=0
            print("inciso c con",k," coches es ",c/365)
        print("inciso D=",numerooptimo, " sin tomar en cuenta costo anual, ganancias de $", incisob)
        print("inciso D=",numerooptimo2,"si tomamos en cuenta costo anual, gananias de $ ",incisob2)
       
  
#%%


print ("la neta me desvelé mucho profe, califiqueme chido")
# Out:
# ganancia 1 coches  = -106129.572291
# inciso a con 1 coches es 2.5397260274
# inciso b con 1 coches es 2.0
# inciso c con 1  coches es  0.953424657534
# ganancia 2 coches  = -27280.280999
# inciso a con 2 coches es 2.4301369863
# inciso b con 2 coches es 1.91830985915
# inciso c con 2  coches es  1.84657534247
# ganancia 3 coches  = 31977.9392106
# inciso a con 3 coches es 2.56438356164
# inciso b con 3 coches es 1.93560606061
# inciso c con 3  coches es  2.75342465753
# ganancia 4 coches  = 78562.0456471
# inciso a con 4 coches es 2.52876712329
# inciso b con 4 coches es 1.95729013255
# inciso c con 4  coches es  3.51506849315
# ganancia 5 coches  = 114531.193822
# inciso a con 5 coches es 2.55616438356
# inciso b con 5 coches es 1.9406779661
# inciso c con 5  coches es  4.24931506849
# ganancia 6 coches  = 94621.2784953
# inciso a con 6 coches es 2.56712328767
# inciso b con 6 coches es 1.98672566372
# inciso c con 6  coches es  4.6904109589
# ganancia 7 coches  = 37757.4813332
# ...
